# %% [markdown]
# # Laboratorio UNIDAD 2
# ## Tipos de datos, Variables, Operaciones Básicas de Entrada y Salida, Operadores Básicos

# %% [markdown]
# ### Ejercicio 1
#
#
# Trabajando con la función print()
#
#
# El comando print(), el cual es una de las directivas más sencillas de Python, simplemente imprime una línea de texto en la pantalla.
#
#
# a) Utiliza la función print() para imprimir la linea ¡Hola, Mundo! en la pantalla. Usa comillas dobles alrededor de la cadena.
#
#
# b) Habiendo hecho eso, usa la función print() nuevamente, pero esta vez imprime tu nombre.
#
#
# c) Elimina las comillas dobles y ejecuta tu código. Mira la reacción de Python. ¿Qué tipo de error arroja?
#
#
# d) Luego, elimina los paréntesis, vuelve a colocar las comillas dobles y ejecuta tu código nuevamente. ¿Qué tipo de error arroja esta vez?

# %%
# a)
print("Hola, Mundo")
# b)
print("Grupo D")
# c)
print(Grupo D)
'''   File "<ipython-input-4-cd290f485aca>", line 6
    print (Grupo D)
           ^
SyntaxError: invalid syntax. Perhaps you forgot a comma? '''
# d)
print "Grupo D"
'''   File "<ipython-input-6-344d20d19bd8>", line 12
    print "Grupo D"
    ^
SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)? '''

# %%
print('"Hola, Mundo"')
# Out:
# "Hola, Mundo"

# %% [markdown]
# ### Ejercicio 2
#
#
# Modifica la primera línea de código, usando las palabras claves reservadas sep y end, para que se obtenga la salida esperada. Emplea dos funciones print() en el editor.
#
#
# No cambies nada en la segunda invocación del print().
#
# ![EJ 2.JPG](data:image/jpeg;base64,...)

# %%
print ("Programming"+"Essentials","in", sep=" ", end=" ")
print ("Python")
# Out:
# Programming Essentials in
# Python

# %%
print('''
# !!!!!!!!!!!!!!!!!!!!!
# !!  hola viajero   !!
# !!                 !!
# !!!!!!!!!!!!!!!!!!!!!''')
# Out:
# !!!!!!!!!!!!!!!!!!!!!
# !!  hola viajero   !!
# !!                 !!
# !!!!!!!!!!!!!!!!!!!!!

# %% [markdown]
# ### Ejercicio 3
#
#
# Escriba un fragmento de código de una línea, utilizando la función print(), así como los caracteres de nueva línea y de escape, para que coincida con el resultado esperado que se muestra en la salida.
#
# ![EJ 3.JPG](data:image/jpeg;base64,...)

# %%
print ('"Estoy"', '"aprendiendo"', '"Python"' , sep= '')  #\n es simil enter.
# Out:
# "Estoy""aprendiendo""Python"

# %% [markdown]
# ### Ejercicio 4
# ¿Qué tipos de literales son los siguientes ejemplos?
# a) "Hola", "007"
# b) "1.5", 2.0, 528, False '''

# %% [markdown]
# a) String, String
#
#
# b) String, Float, String, Booleano

# %%
x= int(25)
y= int(10)
d= x//y #<-- int  parte entera
f= x/y  #<-- float  cociente
g= x%y #<-- int resto

print(d, type(d))
print(f, type(f))
print(g, type(g))
# Out:
# 2 <class 'int'>
# 2.5 <class 'float'>
# 5 <class 'int'>

# %% [markdown]
# ### Ejercicio 5
#
#
# Millas y kilómetros son unidades de longitud o distancia.
#
#
# Teniendo en mente que 1 milla equivale aproximadamente a 1.61 kilómetros, realiza un programa que devuelva la siguiente salida:
#
#
# Convierte de Millas a kilómetros.
#
#
# Convierte de Kilómetros a millas.
#
#
# Ayuda: utiliza la funcion round para redondear a 2 digitos.

# %%
# 1 milla = 1.61 km
m = 1
k = 1.61

'''m = k*1.61
k = m/1.61 '''

valor_km = float(input ("Escriba la cantidad de millas que desea convertir a kilometros:"))
print ("Esas millas serian: ", round(valor_km*k, 2)) #redondeo, 2 decimales

valor_milla = float(input ("Escriba la cantidad de kilometros que desea convertir a millas:"))
print ("Esos kilometros serian: ", round(valor_milla/k, 2))
# Out:
# Escriba la cantidad de millas que desea convertir a kilometros:7.38
# Esas millas serian:  11.9
# Escriba la cantidad de kilometros que desea convertir a millas:12.25
# Esos kilometros serian:  7.6

# %% [markdown]
# ### Ejercicio 6
# Observa el código en el editor: lee un valor float, lo coloca en una variable llamada x, e imprime el
# valor de la variable llamada y.
#
# Tu tarea es completar el código para evaluar la siguiente expresión:
#
# 3x^3 - 2x^2 + 3x - 1
#
#
# El resultado debe ser asignado a y.
#
#
# Ayuda: cambia el tipo de dato para asegurarnos de que x es del tipo float

# %%
x = float(input ("Escoja un valor de X: "))
formula = 3*x**3-2*x**2+3*x-1

print ("El resultado es: ", formula)
# Out:
# Escoja un valor de X: -1
# El resultado es:  -9.0

# %% [markdown]
# ### Ejercicio 7
# Responde las siguientes preguntas)
#
# ¿Cuál es la salida del siguiente fragmento de código?
#
# ![7.JPG](data:image/jpeg;base64,...)
#
#
# **1. 3**
#
# ~~2. 2~~
#
# ~~3. 5~~

# %% [markdown]
# b) ¿Cuáles de los siguientes nombres de variables son ilegales/incorrectas en Python?
#
#
# 1. ~~my_var~~
#
#
# 2. ~~m~~
#
#
# 3. **101**
#
#
# 4. ~~averylongVariablename~~
#
#
# 5. ~~m101~~
#
#
# 6. **m 101**
#
#
# 7. ~~Del~~
#
#
# 8. **del**

# %% [markdown]
# c) ¿Cuál es el resultado del siguiente fragmento?
#
# ![7C.JPG](data:image/jpeg;base64,...)
#
# 1. ~~1~~
# 2. **11**
# 3. ~~2~~
# 4. ~~Error~~

# %% [markdown]
# d) ¿Cuál es el resultado del siguiente fragmento?
#
# ![7D.JPG](data:image/jpeg;base64,...)
#
# 1. **1.0**
# 2. ~~1~~
# 3. ~~9~~
# 4. ~~6~~
# 5. ~~6.0~~

# %% [markdown]
#  ### Ejercicio 8
#
#
# Responde las siguientes preguntas
#
#
# a) El dígrafo \n obliga a la función print() a:
#
#
# 1. **realizar un salto de línea**
#
#
# 2. ~~imprimir exactamente dos caracteres: \ y n~~
#
#
# 3. ~~duplicar el carácter al lado del dígrafo~~
#
#
# 4. ~~detener su ejecución~~

# %% [markdown]
# b) El significado del parámetro de palabra clave está determinado por:
#
#
# 1. **el nombre del argumento especificado junto con su valor**
#
#
# 2. ~~su posición dentro de la lista de argumentos~~
#
#
# 3. ~~su conexión con las variables existentes~~
#
#
# 4. ~~es valioso~~

# %% [markdown]
# c) El operador **:
# 1. **realiza exponenciación**
# 2. ~~no existe~~
# 3. ~~realiza la multiplicación de punto flotante~~
# 4. ~~realiza multiplicaciones duplicadas~~

# %% [markdown]
# d) El resultado de dividir 1/1 es:
# 1. **es igual a 1.0**
# 2. ~~es igual a 1~~
# 3. ~~no puede ser evaluado~~
# 4. ~~no se puede predecir~~

# %% [markdown]
# e) ¿Cuál es el resultado del siguiente fragmento?
#
# ![8e.JPG](data:image/jpeg;base64,...)
# 1. **2 1**
# 2. ~~1 2~~
# 3. ~~1 1~~
# 4. ~~2 2~~

# %% [markdown]
# ### Ejercicio 9
# Realizar la carga de dos números enteros por teclado e imprimir su suma y su producto

# %%
n1 = int(input ("Ingrese el primer numero: "))
n2 = int(input ("Ingrese el segundo numero: "))
print ("La suma de los numeros es:", n1+n2)
print ("La multiplicacion de los numeros es: ", n1*n2)
# Out:
# Ingrese el primer numero: 2
# Ingrese el segundo numero: 3
# La suma de los numeros es: 5
# La multiplicacion de los numeros es:  6

# %% [markdown]
# ### Ejercicio 10
# Realizar la carga del precio de un producto y la cantidad a llevar. Mostrar cuanto se debe pagar (se
# ingresa un valor entero en el precio del producto)

# %%
p = float(input ("Ingrese precio del producto: "))
v = float(input ("Ingrese valor del producto: "))
print ("Se debe abonar: $", p*v)
# Out:
# Ingrese precio del producto: 50
# Ingrese valor del producto: 10
# Se debe abonar: $ 500.0

# %% [markdown]
# ### Ejercicio 11
# Realizar la carga del lado de un cuadrado, mostrar por pantalla el perímetro del mismo (El perímetro
# de un cuadrado se calcula multiplicando el valor del lado por cuatro)

# %%
lado = float(input ("Ingrese el tamaño del lado: "))
print ("El perimetro de un cuadrado con esos lados seria de: ", lado*4)
# Out:
# Ingrese el tamaño del lado: 10
# El perimetro de un cuadrado con esos lados seria de:  40.0

# %% [markdown]
# ### Ejercicio 12
# Escribir un programa en el cual se ingresen cuatro números, calcular e informar la suma de los dos
# primeros y el producto del tercero y el cuarto.

# %%
n1 = float(input("Ingrese el primer valor: "))
n2 = float(input("Ingrese el segundo valor: "))
n3 = float(input("Ingrese el tercer valor: "))
n4 = float(input("Ingrese el cuarto valor: "))

print ("La suma de los primeros 2 es de: ", n1+n2, "Y el producto de los ultimos es de: ", n3*n4)
# Out:
# Ingrese el primer valor: 2
# Ingrese el segundo valor: 2
# Ingrese el tercer valor: 3
# Ingrese el cuarto valor: 4
# La suma de los primeros 2 es de:  4.0 Y el producto de los ultimos es de:  12.0

# %% [markdown]
# ### Ejercicio 13
# Realizar un programa que lea cuatro valores numéricos e informar su suma y promedio.

# %%
n1 = float(input("Ingrese el primer valor: "))
n2 = float(input("Ingrese el segundo valor: "))
n3 = float(input("Ingrese el tercer valor: "))
n4 = float(input("Ingrese el cuarto valor: "))

print ("La suma de los numeros es de:", n1+n2+n3+n4, "Y el promedio es de: ", (n1+n2+n3+n4)/4)
# Out:
# Ingrese el primer valor: 1
# Ingrese el segundo valor: 2
# Ingrese el tercer valor: 3
# Ingrese el cuarto valor: 4
# La suma de los numeros es de: 10.0 Y el promedio es de:  2.5

# %% [markdown]
# ### Ejercicio 14
# Calcular el sueldo mensual de un operario conociendo la cantidad de horas trabajadas y el valor por
# hora.

# %%
cant_h = float(input ("Indique cantidad de horas trabajadas: "))
valor_h = float(input ("Indique valor hora: "))

print ("El sueldo correspondiente es de: ", cant_h*valor_h)
# Out:
# Indique cantidad de horas trabajadas: 10
# Indique valor hora: 100
# El sueldo correspondiente es de:  1000.0

# %% [markdown]
# ### Ejercicio 15
# Escribir un programa que muestre por pantalla el resultado de la siguiente operación aritmética
#
# ![15.JPG](data:image/jpeg;base64,...)

# %%
print (((3+2)/2.5)**2)
# Out:
# 4.0

# %% [markdown]
# ###Ejercicio 16
# Escribir un programa que lea un entero positivo, introducido por el usuario y después muestre en
# pantalla la suma de todos los enteros desde 1 hasta n.
#
# La suma de los primeros enteros positivos
# puede ser calculada de la siguiente forma:
#
# ![16.JPG](data:image/jpeg;base64,...)

# %%
n = int(input("Ingrese un valor: "))
suma = (n*(n+1))/2
print(suma)
# Out:
# Ingrese un valor: 5
# 15.0

# %% [markdown]
# ### Ejercicio 17
# Escribir un programa que pida al usuario dos números enteros y muestre por pantalla la <n> entre
# <m> da un cociente <c> y un resto <r> donde <n> y <m> son los números introducidos por el usuario, y
# <c> y <r> son el cociente y el resto de la división entera respectivamente.

# %%
n1 = float(input("Ingrese el primer valor: "))
n2 = float(input("Ingrese el segundo valor: "))
cos = n1/n2   #<--- COCIENTE
r = n1%n2   #<--- RESTO
print ("El cociente es: ", cos)
print ("El resto es: ", r)
# Out:
# Ingrese el primer valor: 10
# Ingrese el segundo valor: 5
# El cociente es:  2.0
# El resto es:  0.0

# %% [markdown]
# ### Ejercicio 18
# Una juguetería tiene mucho éxito en dos de sus productos: payasos y muñecas. Suele hacer venta por
# correo y la empresa de logística les cobra por peso de cada paquete así que deben calcular el peso de
# los payasos y muñecas que saldrán en cada paquete a demanda. Cada payaso pesa 112 g y cada
# muñeca 75 g. Escribir un programa que lea el número de payasos y muñecas vendidos en el último
# pedido y calcule el peso total del paquete que será enviado.

# %%
#peso = 112g (payasos)
#peso = 75g (muñecas)
cant_pay  = int (input("Ingrese cantidad de payasos: "))
cant_mun  = int (input("Ingrese cantidad de muniecas: "))
print ("El peso del paquete es de: ", (cant_pay*112)+(cant_mun*75))
# Out:
# Ingrese cantidad de payasos: 10
# Ingrese cantidad de muniecas: 10
# El peso del paquete es de:  1870

# %% [markdown]
# ### Ejercicio 19
# Una panadería vende barras de pan a $3.49 cada una. El pan que no es el día tiene un descuento del
# 60%. Escribir un programa que comience leyendo el número de barras vendidas que no son del día.
# Después el programa debe mostrar el precio habitual de una barra de pan, el descuento que se le hace
# por no ser fresca y el costo final total.

# %%
p_pan = 3.49
panvenc = int(input("Ingrese cantidad de barras vendidas que no son del dia: "))
desc = p_pan*panvenc*0.6
print("Barra de pan:", p_pan, "\nTotal pan: ", p_pan*panvenc, "\nDescuento por barras vencidas: $ ", desc, "\nCosto final total: ", (p_pan*panvenc)-desc)
# Out:
# Ingrese cantidad de barras vendidas que no son del dia: 10
# Barra de pan: 3.49
# Total pan:  34.900000000000006
# Descuento por barras vencidas: $  20.94
# Costo final total:  13.960000000000004

# %% [markdown]
# ### Ejercicio 20
# Escribir un programa que pregunte el nombre del usuario en la consola y un número entero e imprima
# por pantalla en líneas distintas el nombre del usuario tantas veces como el número introducido.

# %%
nom = input ("Ingrese su nombre: ")
n = int(input("Ingrese un numero: "))
print ((nom + "\n") * n)
# Out:
# Ingrese su nombre: Grupo D
# Ingrese un numero: 10
# Grupo D
# Grupo D
# Grupo D
# Grupo D
# Grupo D
# Grupo D
# Grupo D
# Grupo D
# Grupo D
# Grupo D

# %% [markdown]
# ### Ejercicio 21
# Se desea calcular la distancia recorrida (m) por un móvil que tiene velocidad constante (m/s) durante
# un tiempo t (s), considerar que es un MRU (Movimiento Rectilíneo Uniforme).
#
# ![20a.JPG](data:image/jpeg;base64,...)
#
# Se sabe que el cálculo de la velocidad en MRU es por formula:
#
# ![20b.JPG](data:image/jpeg;base64,...)
#
# Despejando la distancia se tiene: 𝑫=𝑽 𝒙 �

# %%
V=float(input("Ingrese la velocidad constante en [m/s]: "))
T=float(input("Ingrese el tiempo en [s]: "))
print("\nLa distancia recorrida es de: ",round(V*T,2),"[m]")
# Out:
# Ingrese la velocidad constante en [m/s]: 10
# Ingrese el tiempo en [s]: 5
#
# La distancia recorrida es de:  50.0 [m]

# %% [markdown]
# ### Ejercicio 22
# Elaborar un algoritmo que permita ingresar el número de partidos ganados, perdidos y empatados,
# por ABC club en el torneo apertura, se debe de mostrar su puntaje total, teniendo en cuenta que por
# cada partido ganado obtendrá 3 puntos, empatado 1 punto y perdido 0 puntos.

# %%
p_gan = int (input("Ingrese cantidad de partidos ganados: "))
p_emp = int (input("Ingrese cantidad de partidos empatados: "))
p_per = int (input("Ingrese cantidad de partidos perdidos: "))

win = 3
tie = 1

print ("El total de los pertidos fue de: ", p_gan+p_emp+p_per, "\nEl puntaje total es: ", p_gan*win + p_emp*tie)
# Out:
# Ingrese cantidad de partidos ganados: 3
# Ingrese cantidad de partidos empatados: 1
# Ingrese cantidad de partidos perdidos: 1
# El total de los pertidos fue de:  5
# El puntaje total es:  10
